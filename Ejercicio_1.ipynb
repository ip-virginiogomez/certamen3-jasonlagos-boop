# %%
velocidades = []

for i in range(5):
    velocidad = int(input(f"Ingrese la velocidad {i+1}: "))
    velocidades.append(velocidad)

print("\nVelocidades registradas:", velocidades)

promedio = sum(velocidades) / len(velocidades)
maxima = max(velocidades)

print(f"Promedio de velocidad: {promedio:.2f} km/h")
print(f"Velocidad máxima: {maxima} km/h")

dentro_limite = True 
peligro = False

for velocidad in velocidades:

    if velocidad < 60 or velocidad > 120:
        dentro_limite = False

    if velocidad > 140 or velocidad < 20:
        peligro = True

if dentro_limite:
    print("Todas las velocidades están dentro del límite permitido.")
else:
    print("Hay velocidades fuera del límite permitido.")

if peligro:
    print("Advertencia: Se detectó una velocidad peligrosa.")
# Out:
# Velocidades registradas: [45, 78, 10, 78, 90]
# Promedio de velocidad: 60.20 km/h
# Velocidad máxima: 90 km/h
# Hay velocidades fuera del límite permitido.
# Advertencia: Se detectó una velocidad peligrosa.
